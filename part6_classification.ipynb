# %% [markdown]
# # AutoML does Classification too!
#
# Here's a prior experiment on classifying Christmas Movies vs Non-Christmas Movies I ran in the Azure Portal to classify Die Hard.

# %%
# Load the workspace information from config.json using the Azure ML SDK
from azureml.core import Workspace

ws = Workspace.from_config()
ws.name
# Out:
# 'DataScience'

# %%
# List all available primary classification metrics, for reference
from azureml.train.automl.utilities import get_primary_metrics

get_primary_metrics('classification')
# Out:
# ['accuracy',
#  'norm_macro_recall',
#  'average_precision_score_weighted',
#  'precision_score_weighted',
#  'AUC_weighted']

# %%
from azureml.core import Experiment

experiment = Experiment(ws, 'DieHardChristmas')
experiment
# Out:
# Experiment(Name: DieHardChristmas,
# Workspace: DataScience)

# %%
from azureml.widgets import RunDetails

# Get the most recent run
run = next(experiment.get_runs())
# Or explicitly by ID: run = AutoMLRun(experiment, 'AutoML_e5ca49e8-6904-4f46-aef6-d835d95a1aa7')

# Display details of that run
RunDetails(run).show()
# Out:
# _AutoMLWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', 's…

# %%
# Grab the resulting model and best run
best_auto_run, automl_model = run.get_output()

# Display details about the best run
RunDetails(best_auto_run).show()
# Out:
# WARNING:root:The version of the SDK does not match the version the model was trained on.
# WARNING:root:The consistency in the result may not be guaranteed.
# WARNING:root:Package:azureml-automl-core, training version:1.35.0, current version:1.40.0
# Package:azureml-automl-runtime, training version:1.35.0, current version:1.40.0
# Package:azureml-core, training version:1.35.0, current version:1.40.0
# Package:azureml-dataprep, training version:2.23.2, current version:3.0.2
# Package:azureml-dataprep-rslex, training version:1.21.2, current version:2.4.2
# Package:azureml-dataset-runtime, training version:1.35.0, current version:1.40.0
# Package:azureml-defaults, training version:1.35.0, current version:1.40.0
# Package:azureml-interpret, training version:1.35.0, current version:1.40.0
# Package:azureml-mlflow, training version:1.35.0, current version:1.40.0
# Package:azureml-pipeline-core, training version:1.35.0, current version:1.40.0
# ...
